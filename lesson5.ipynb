# %%
#loops
# while
# for

# %%
student_age = 22.5
cloud_class_students_ages1 = {23,33,23,45,45,56,56,56,53,34,45} # set
cloud_class_students_ages2 = [23,33,23,45,45,56,56,56,53,34,45] # list
cloud_class_students_ages3 = (23,33,23,45,45,56,56,56,53,34,45) # tuple
computer_specs = {'color':"silver","price":230.7,'weight':3.5} # dictionary  #'key':value

# #atomic values
# int: 24234,-3453,23
# num = 3423423
# float:234.0,-23.342
# boolean:True,False
# string: 'asfasdf', "asfafasd234","""asdfas""",'''asdfafafa34'''
# #collections
# list:  []
# tuple: ()
# dictionary-pairs(key:value): {}
# set: {}

# range()

print(type(computer_specs))

# %%
cloud_class_students_ages2 = [23,33,23,45,45,56,56,56,53,34,45]
indexing: cloud_class_students_ages2[7]
print(cloud_class_students_ages2[7])
print(cloud_class_students_ages2[-1])

# %%
print(cloud_class_students_ages1)

# %%
print(cloud_class_students_ages2)
for item in cloud_class_students_ages2:
    print(item)

# %%
# in, not in

'az' in "ali"

# %%
c = 0
for part in "we are learning python, class cloud":
    print(part)
    c += 1 # c = c + 1
print(c)
