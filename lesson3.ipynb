# %%
# conditional statements

# if -- one block-one option

# if else -- two block-two options

# if elif else -- multi blocks

# %%
# condition
# conditional operators

# >  greater than
# <  less than
# >= greater than or equal
# <= less than or equal
# == equal
# != not equal

# %%
# 10 > 100  --> logical expression / boolean expression

print(10 > 100)   # False

# a + 23 / 4  --> arithmetic expression
# Out:
# False

# %%
marks = 65
passing = 60
marks >= passing
# Out:
# True

# %%
if marks >= passing:
    print("Congratulations you're passed you'have obtained", marks)

# %%
if marks >= passing:
    print("Congratulations you're passed you'have obtained", marks)
else:
    print("sorry, you're Failed try agian")
